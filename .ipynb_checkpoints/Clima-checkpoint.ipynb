# %% [markdown]
# # PROGRAMA DE MODELACION MATEMATICA PARA EL DESARROLLO DE PLANES Y PROYECTOS DE NEGOCIO I
#
# ## Pronósticos de carga industriales
#
# #### Equipo:
# * *Andrea Lizette Contreras González*
# * *Alberto Enrique Nuño Guevara*
# * *Axel Francisco Munguía Quintero*

# %% [markdown]
# **1. Descarga de datos climáticos**

# %%
from wwo_hist import retrieve_hist_data
frequency = 1
start_date = "01-01-2009"
end_date = "02-21-2020"
api_key = "48236d9a55ec414e930211450201802"
#location_list = ["Celaya","Irapuato","Guanajuato","San Miguel de Allende","Aguascalientes",
   #              "Fresnillo","Matehuala","San Luis Potosí"]
location_list = ["Guadalajara"]
#san miguel de allende

hist_weather_data = retrieve_hist_data(api_key,
                                location_list,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Guadalajara
#
#
# Currently retrieving data for Guadalajara: from 2009-02-21 to 2009-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:01.067499
# Currently retrieving data for Guadalajara: from 2009-03-01 to 2009-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.516618
# Currently retrieving data for Guadalajara: from 2009-04-01 to 2009-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.079974
# Currently retrieving data for Guadalajara: from 2009-05-01 to 2009-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.629581
# Currently retrieving data for Guadalajara: from 2009-06-01 to 2009-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:11.896006
# Currently retrieving data for Guadalajara: from 2009-07-01 to 2009-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:14.244793
# Currently retrieving data for Guadalajara: from 2009-08-01 to 2009-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:16.733038
# Currently retrieving data for Guadalajara: from 2009-09-01 to 2009-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:19.096954
# Currently retrieving data for Guadalajara: from 2009-10-01 to 2009-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:21.784391
# Currently retrieving data for Guadalajara: from 2009-11-01 to 2009-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:24.215402
# Currently retrieving data for Guadalajara: from 2009-12-01 to 2009-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:26.634513
# Currently retrieving data for Guadalajara: from 2010-01-01 to 2010-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:27.614656
# Currently retrieving data for Guadalajara: from 2010-02-01 to 2010-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:28.392959
# Currently retrieving data for Guadalajara: from 2010-03-01 to 2010-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:29.351700
# Currently retrieving data for Guadalajara: from 2010-04-01 to 2010-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:31.760120
# Currently retrieving data for Guadalajara: from 2010-05-01 to 2010-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:34.153766
# Currently retrieving data for Guadalajara: from 2010-06-01 to 2010-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:36.682374
# Currently retrieving data for Guadalajara: from 2010-07-01 to 2010-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:39.158659
# Currently retrieving data for Guadalajara: from 2010-08-01 to 2010-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:43.127301
# Currently retrieving data for Guadalajara: from 2010-09-01 to 2010-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:45.819620
# Currently retrieving data for Guadalajara: from 2010-10-01 to 2010-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:48.578286
# Currently retrieving data for Guadalajara: from 2010-11-01 to 2010-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:50.953007
# Currently retrieving data for Guadalajara: from 2010-12-01 to 2010-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:53.413748
# Currently retrieving data for Guadalajara: from 2011-01-01 to 2011-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:55.915301
# Currently retrieving data for Guadalajara: from 2011-02-01 to 2011-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:58.164563
# Currently retrieving data for Guadalajara: from 2011-03-01 to 2011-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:00.737500
# Currently retrieving data for Guadalajara: from 2011-04-01 to 2011-04-30
# Time elapsed (hh:mm:ss.ms) 0:01:03.118344
# Currently retrieving data for Guadalajara: from 2011-05-01 to 2011-05-31
# Time elapsed (hh:mm:ss.ms) 0:01:06.373992
# Currently retrieving data for Guadalajara: from 2011-06-01 to 2011-06-30
# Time elapsed (hh:mm:ss.ms) 0:01:09.031063
# Currently retrieving data for Guadalajara: from 2011-07-01 to 2011-07-31
# Time elapsed (hh:mm:ss.ms) 0:01:11.652934
# Currently retrieving data for Guadalajara: from 2011-08-01 to 2011-08-31
# Time elapsed (hh:mm:ss.ms) 0:01:14.469936
# Currently retrieving data for Guadalajara: from 2011-09-01 to 2011-09-30
# Time elapsed (hh:mm:ss.ms) 0:01:16.981337
# Currently retrieving data for Guadalajara: from 2011-10-01 to 2011-10-31
# Time elapsed (hh:mm:ss.ms) 0:01:19.461495
# Currently retrieving data for Guadalajara: from 2011-11-01 to 2011-11-30
# Time elapsed (hh:mm:ss.ms) 0:01:22.082029
# Currently retrieving data for Guadalajara: from 2011-12-01 to 2011-12-31
# Time elapsed (hh:mm:ss.ms) 0:01:25.042642
# Currently retrieving data for Guadalajara: from 2012-01-01 to 2012-01-31
# Time elapsed (hh:mm:ss.ms) 0:01:27.445613
# Currently retrieving data for Guadalajara: from 2012-02-01 to 2012-02-29
# Time elapsed (hh:mm:ss.ms) 0:01:30.073947
# Currently retrieving data for Guadalajara: from 2012-03-01 to 2012-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:32.994274
# Currently retrieving data for Guadalajara: from 2012-04-01 to 2012-04-30
# Time elapsed (hh:mm:ss.ms) 0:01:35.379477
# Currently retrieving data for Guadalajara: from 2012-05-01 to 2012-05-31
# Time elapsed (hh:mm:ss.ms) 0:01:38.959522
# Currently retrieving data for Guadalajara: from 2012-06-01 to 2012-06-30
# Time elapsed (hh:mm:ss.ms) 0:01:41.361418
# Currently retrieving data for Guadalajara: from 2012-07-01 to 2012-07-31
# Time elapsed (hh:mm:ss.ms) 0:01:44.011918
# Currently retrieving data for Guadalajara: from 2012-08-01 to 2012-08-31
# Time elapsed (hh:mm:ss.ms) 0:01:46.426928
# Currently retrieving data for Guadalajara: from 2012-09-01 to 2012-09-30
# Time elapsed (hh:mm:ss.ms) 0:01:49.203353
# Currently retrieving data for Guadalajara: from 2012-10-01 to 2012-10-31
# Time elapsed (hh:mm:ss.ms) 0:01:51.706797
# Currently retrieving data for Guadalajara: from 2012-11-01 to 2012-11-30
# Time elapsed (hh:mm:ss.ms) 0:01:54.140247
# Currently retrieving data for Guadalajara: from 2012-12-01 to 2012-12-31
# Time elapsed (hh:mm:ss.ms) 0:01:57.039262
# Currently retrieving data for Guadalajara: from 2013-01-01 to 2013-01-31
# Time elapsed (hh:mm:ss.ms) 0:01:59.793423
# Currently retrieving data for Guadalajara: from 2013-02-01 to 2013-02-28
# Time elapsed (hh:mm:ss.ms) 0:02:02.414402
# Currently retrieving data for Guadalajara: from 2013-03-01 to 2013-03-31
# Time elapsed (hh:mm:ss.ms) 0:02:06.095096
# Currently retrieving data for Guadalajara: from 2013-04-01 to 2013-04-30
# Time elapsed (hh:mm:ss.ms) 0:02:08.940968
# Currently retrieving data for Guadalajara: from 2013-05-01 to 2013-05-31
# Time elapsed (hh:mm:ss.ms) 0:02:11.362411
# Currently retrieving data for Guadalajara: from 2013-06-01 to 2013-06-30
# Time elapsed (hh:mm:ss.ms) 0:02:13.790685
# Currently retrieving data for Guadalajara: from 2013-07-01 to 2013-07-31
# Time elapsed (hh:mm:ss.ms) 0:02:16.763117
# Currently retrieving data for Guadalajara: from 2013-08-01 to 2013-08-31
# Time elapsed (hh:mm:ss.ms) 0:02:19.323189
# Currently retrieving data for Guadalajara: from 2013-09-01 to 2013-09-30
# Time elapsed (hh:mm:ss.ms) 0:02:21.840455
# Currently retrieving data for Guadalajara: from 2013-10-01 to 2013-10-31
# Time elapsed (hh:mm:ss.ms) 0:02:24.241777
# Currently retrieving data for Guadalajara: from 2013-11-01 to 2013-11-30
# Time elapsed (hh:mm:ss.ms) 0:02:26.624133
# Currently retrieving data for Guadalajara: from 2013-12-01 to 2013-12-31
# Time elapsed (hh:mm:ss.ms) 0:02:29.259710
# Currently retrieving data for Guadalajara: from 2014-01-01 to 2014-01-31
# Time elapsed (hh:mm:ss.ms) 0:02:31.750459
# Currently retrieving data for Guadalajara: from 2014-02-01 to 2014-02-28
# Time elapsed (hh:mm:ss.ms) 0:02:34.060597
# Currently retrieving data for Guadalajara: from 2014-03-01 to 2014-03-31
# Time elapsed (hh:mm:ss.ms) 0:02:36.532767
# Currently retrieving data for Guadalajara: from 2014-04-01 to 2014-04-30
# Time elapsed (hh:mm:ss.ms) 0:02:38.951720
# Currently retrieving data for Guadalajara: from 2014-05-01 to 2014-05-31
# Time elapsed (hh:mm:ss.ms) 0:02:41.356497
# Currently retrieving data for Guadalajara: from 2014-06-01 to 2014-06-30
# Time elapsed (hh:mm:ss.ms) 0:02:43.754104
# Currently retrieving data for Guadalajara: from 2014-07-01 to 2014-07-31
# Time elapsed (hh:mm:ss.ms) 0:02:47.388773
# Currently retrieving data for Guadalajara: from 2014-08-01 to 2014-08-31
# Time elapsed (hh:mm:ss.ms) 0:02:50.211524
# Currently retrieving data for Guadalajara: from 2014-09-01 to 2014-09-30
# Time elapsed (hh:mm:ss.ms) 0:02:52.577690
# Currently retrieving data for Guadalajara: from 2014-10-01 to 2014-10-31
# Time elapsed (hh:mm:ss.ms) 0:02:55.030898
# Currently retrieving data for Guadalajara: from 2014-11-01 to 2014-11-30
# Time elapsed (hh:mm:ss.ms) 0:02:57.407205
# Currently retrieving data for Guadalajara: from 2014-12-01 to 2014-12-31
# Time elapsed (hh:mm:ss.ms) 0:02:59.846911
# Currently retrieving data for Guadalajara: from 2015-01-01 to 2015-01-31
# Time elapsed (hh:mm:ss.ms) 0:03:02.454020
# Currently retrieving data for Guadalajara: from 2015-02-01 to 2015-02-28
# Time elapsed (hh:mm:ss.ms) 0:03:04.805805
# Currently retrieving data for Guadalajara: from 2015-03-01 to 2015-03-31
# Time elapsed (hh:mm:ss.ms) 0:03:07.312789
# Currently retrieving data for Guadalajara: from 2015-04-01 to 2015-04-30
# Time elapsed (hh:mm:ss.ms) 0:03:11.634203
# Currently retrieving data for Guadalajara: from 2015-05-01 to 2015-05-31
# Time elapsed (hh:mm:ss.ms) 0:03:14.142137
# Currently retrieving data for Guadalajara: from 2015-06-01 to 2015-06-30
# Time elapsed (hh:mm:ss.ms) 0:03:16.564252
# Currently retrieving data for Guadalajara: from 2015-07-01 to 2015-07-31
# Time elapsed (hh:mm:ss.ms) 0:03:19.074694
# Currently retrieving data for Guadalajara: from 2015-08-01 to 2015-08-31
# Time elapsed (hh:mm:ss.ms) 0:03:21.594726
# Currently retrieving data for Guadalajara: from 2015-09-01 to 2015-09-30
# Time elapsed (hh:mm:ss.ms) 0:03:24.184730
# Currently retrieving data for Guadalajara: from 2015-10-01 to 2015-10-31
# Time elapsed (hh:mm:ss.ms) 0:03:26.673441
# Currently retrieving data for Guadalajara: from 2015-11-01 to 2015-11-30
# Time elapsed (hh:mm:ss.ms) 0:03:29.142768
# Currently retrieving data for Guadalajara: from 2015-12-01 to 2015-12-31
# Time elapsed (hh:mm:ss.ms) 0:03:31.671666
# Currently retrieving data for Guadalajara: from 2016-01-01 to 2016-01-31
# Time elapsed (hh:mm:ss.ms) 0:03:34.113068
# Currently retrieving data for Guadalajara: from 2016-02-01 to 2016-02-29
# Time elapsed (hh:mm:ss.ms) 0:03:36.403312
# Currently retrieving data for Guadalajara: from 2016-03-01 to 2016-03-31
# Time elapsed (hh:mm:ss.ms) 0:03:39.172147
# Currently retrieving data for Guadalajara: from 2016-04-01 to 2016-04-30
# Time elapsed (hh:mm:ss.ms) 0:03:41.750005
# Currently retrieving data for Guadalajara: from 2016-05-01 to 2016-05-31
# Time elapsed (hh:mm:ss.ms) 0:03:44.648295
# Currently retrieving data for Guadalajara: from 2016-06-01 to 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:03:47.163981
# Currently retrieving data for Guadalajara: from 2016-07-01 to 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:03:49.957816
# Currently retrieving data for Guadalajara: from 2016-08-01 to 2016-08-31
# Time elapsed (hh:mm:ss.ms) 0:03:52.485212
# Currently retrieving data for Guadalajara: from 2016-09-01 to 2016-09-30
# Time elapsed (hh:mm:ss.ms) 0:03:55.071098
# Currently retrieving data for Guadalajara: from 2016-10-01 to 2016-10-31
# Time elapsed (hh:mm:ss.ms) 0:03:58.085758
# Currently retrieving data for Guadalajara: from 2016-11-01 to 2016-11-30
# Time elapsed (hh:mm:ss.ms) 0:04:00.542431
# Currently retrieving data for Guadalajara: from 2016-12-01 to 2016-12-31
# Time elapsed (hh:mm:ss.ms) 0:04:03.301767
# Currently retrieving data for Guadalajara: from 2017-01-01 to 2017-01-31
# Time elapsed (hh:mm:ss.ms) 0:04:06.316579
# Currently retrieving data for Guadalajara: from 2017-02-01 to 2017-02-28
# Time elapsed (hh:mm:ss.ms) 0:04:08.681881
# Currently retrieving data for Guadalajara: from 2017-03-01 to 2017-03-31
# Time elapsed (hh:mm:ss.ms) 0:04:11.261363
# Currently retrieving data for Guadalajara: from 2017-04-01 to 2017-04-30
# Time elapsed (hh:mm:ss.ms) 0:04:13.838541
# Currently retrieving data for Guadalajara: from 2017-05-01 to 2017-05-31
# Time elapsed (hh:mm:ss.ms) 0:04:17.714546
# Currently retrieving data for Guadalajara: from 2017-06-01 to 2017-06-30
# Time elapsed (hh:mm:ss.ms) 0:04:20.201108
# Currently retrieving data for Guadalajara: from 2017-07-01 to 2017-07-31
# Time elapsed (hh:mm:ss.ms) 0:04:22.949993
# Currently retrieving data for Guadalajara: from 2017-08-01 to 2017-08-31
# Time elapsed (hh:mm:ss.ms) 0:04:25.511196
# Currently retrieving data for Guadalajara: from 2017-09-01 to 2017-09-30
# Time elapsed (hh:mm:ss.ms) 0:04:27.982609
# Currently retrieving data for Guadalajara: from 2017-10-01 to 2017-10-31
# Time elapsed (hh:mm:ss.ms) 0:04:30.760074
# Currently retrieving data for Guadalajara: from 2017-11-01 to 2017-11-30
# Time elapsed (hh:mm:ss.ms) 0:04:33.522905
# Currently retrieving data for Guadalajara: from 2017-12-01 to 2017-12-31
# Time elapsed (hh:mm:ss.ms) 0:04:36.029963
# Currently retrieving data for Guadalajara: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:04:38.673039
# Currently retrieving data for Guadalajara: from 2018-02-01 to 2018-02-28
# Time elapsed (hh:mm:ss.ms) 0:04:40.987170
# Currently retrieving data for Guadalajara: from 2018-03-01 to 2018-03-31
# Time elapsed (hh:mm:ss.ms) 0:04:43.473995
# Currently retrieving data for Guadalajara: from 2018-04-01 to 2018-04-30
# Time elapsed (hh:mm:ss.ms) 0:04:46.564648
# Currently retrieving data for Guadalajara: from 2018-05-01 to 2018-05-31
# Time elapsed (hh:mm:ss.ms) 0:04:50.108574
# Currently retrieving data for Guadalajara: from 2018-06-01 to 2018-06-30
# Time elapsed (hh:mm:ss.ms) 0:04:52.909045
# Currently retrieving data for Guadalajara: from 2018-07-01 to 2018-07-31
# Time elapsed (hh:mm:ss.ms) 0:04:55.461676
# Currently retrieving data for Guadalajara: from 2018-08-01 to 2018-08-31
# Time elapsed (hh:mm:ss.ms) 0:04:57.977641
# Currently retrieving data for Guadalajara: from 2018-09-01 to 2018-09-30
# Time elapsed (hh:mm:ss.ms) 0:05:00.710521
# Currently retrieving data for Guadalajara: from 2018-10-01 to 2018-10-31
# Time elapsed (hh:mm:ss.ms) 0:05:03.181956
# Currently retrieving data for Guadalajara: from 2018-11-01 to 2018-11-30
# Time elapsed (hh:mm:ss.ms) 0:05:05.789323
# Currently retrieving data for Guadalajara: from 2018-12-01 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:05:08.356510
# Currently retrieving data for Guadalajara: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:05:11.361121
# Currently retrieving data for Guadalajara: from 2019-02-01 to 2019-02-28
# Time elapsed (hh:mm:ss.ms) 0:05:14.639422
# Currently retrieving data for Guadalajara: from 2019-03-01 to 2019-03-31
# Time elapsed (hh:mm:ss.ms) 0:05:17.735377
# Currently retrieving data for Guadalajara: from 2019-04-01 to 2019-04-30
# Time elapsed (hh:mm:ss.ms) 0:05:20.493973
# Currently retrieving data for Guadalajara: from 2019-05-01 to 2019-05-31
# Time elapsed (hh:mm:ss.ms) 0:05:23.037833
# Currently retrieving data for Guadalajara: from 2019-06-01 to 2019-06-30
# Time elapsed (hh:mm:ss.ms) 0:05:25.509577
# Currently retrieving data for Guadalajara: from 2019-07-01 to 2019-07-31
# Time elapsed (hh:mm:ss.ms) 0:05:28.695600
# Currently retrieving data for Guadalajara: from 2019-08-01 to 2019-08-31
# Time elapsed (hh:mm:ss.ms) 0:05:31.332615
# Currently retrieving data for Guadalajara: from 2019-09-01 to 2019-09-30
# Time elapsed (hh:mm:ss.ms) 0:05:34.231907
# Currently retrieving data for Guadalajara: from 2019-10-01 to 2019-10-31
# Time elapsed (hh:mm:ss.ms) 0:05:36.884807
# Currently retrieving data for Guadalajara: from 2019-11-01 to 2019-11-30
# Time elapsed (hh:mm:ss.ms) 0:05:39.436785
# Currently retrieving data for Guadalajara: from 2019-12-01 to 2019-12-31
# Time elapsed (hh:mm:ss.ms) 0:05:42.354258
# Currently retrieving data for Guadalajara: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:05:45.000598
# Currently retrieving data for Guadalajara: from 2020-02-01 to 2020-02-21
# Time elapsed (hh:mm:ss.ms) 0:05:46.979183
#
#
# export Guadalajara completed!
