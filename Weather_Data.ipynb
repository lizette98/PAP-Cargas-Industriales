# %% [markdown]
# ## PROGRAMA DE MODELACION MATEMATICA PARA EL DESARROLLO DE PLANES Y PROYECTOS DE NEGOCIO I
# ### Pronósticos de carga industriales
# ##### Equipo:
# * Andrea Lizette Contreras González
# * Alberto Enrique Nuño Guevara
# * Axel Francisco Munguía Quintero
# #### 1. Descarga de datos climáticos

# %%
from wwo_hist import retrieve_hist_data
frequency = 1
start_date = "01-01-2009"
end_date = "02-21-2020"
api_key = "750139f82081441682b231906202702"

#location_list = ["Tecoman", "Jiquilpan", "Morelia", "Zamora", "Uruapan", "Zitacuaro", "Manzanillo o La Manzanilla", "Villa de Álvarez"]

location_list = ["La_Manzanilla"]

hist_weather_data = retrieve_hist_data(api_key,
                                location_list,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for La_Manzanilla
#
#
# Currently retrieving data for La_Manzanilla: from 2009-01-01 to 2009-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.917534
# Currently retrieving data for La_Manzanilla: from 2009-02-01 to 2009-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:09.265126
# Currently retrieving data for La_Manzanilla: from 2009-03-01 to 2009-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:12.836017
# Currently retrieving data for La_Manzanilla: from 2009-04-01 to 2009-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:16.264065
# Currently retrieving data for La_Manzanilla: from 2009-05-01 to 2009-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:19.849807
# Currently retrieving data for La_Manzanilla: from 2009-06-01 to 2009-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:24.379621
# Currently retrieving data for La_Manzanilla: from 2009-07-01 to 2009-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:27.779173
# Currently retrieving data for La_Manzanilla: from 2009-08-01 to 2009-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:33.550173
# Currently retrieving data for La_Manzanilla: from 2009-09-01 to 2009-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:38.999179
# Currently retrieving data for La_Manzanilla: from 2009-10-01 to 2009-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:46.350818
# Currently retrieving data for La_Manzanilla: from 2009-11-01 to 2009-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:52.035349
# Currently retrieving data for La_Manzanilla: from 2009-12-01 to 2009-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:55.593314
# Currently retrieving data for La_Manzanilla: from 2010-01-01 to 2010-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:59.692104
# Currently retrieving data for La_Manzanilla: from 2010-02-01 to 2010-02-28
# Time elapsed (hh:mm:ss.ms) 0:01:02.825011
# Currently retrieving data for La_Manzanilla: from 2010-03-01 to 2010-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:06.641575
# Currently retrieving data for La_Manzanilla: from 2010-04-01 to 2010-04-30
# Time elapsed (hh:mm:ss.ms) 0:01:09.791327
# Currently retrieving data for La_Manzanilla: from 2010-05-01 to 2010-05-31
# Time elapsed (hh:mm:ss.ms) 0:01:13.407676
# Currently retrieving data for La_Manzanilla: from 2010-06-01 to 2010-06-30
# Time elapsed (hh:mm:ss.ms) 0:01:21.039882
# Currently retrieving data for La_Manzanilla: from 2010-07-01 to 2010-07-31
# Time elapsed (hh:mm:ss.ms) 0:01:24.589473
# Currently retrieving data for La_Manzanilla: from 2010-08-01 to 2010-08-31
# Time elapsed (hh:mm:ss.ms) 0:01:33.342866
# Currently retrieving data for La_Manzanilla: from 2010-09-01 to 2010-09-30
# Time elapsed (hh:mm:ss.ms) 0:01:38.921172
# Currently retrieving data for La_Manzanilla: from 2010-10-01 to 2010-10-31
# Time elapsed (hh:mm:ss.ms) 0:01:42.252010
# Currently retrieving data for La_Manzanilla: from 2010-11-01 to 2010-11-30
# Time elapsed (hh:mm:ss.ms) 0:01:45.370799
# Currently retrieving data for La_Manzanilla: from 2010-12-01 to 2010-12-31
# Time elapsed (hh:mm:ss.ms) 0:01:49.154228
# Currently retrieving data for La_Manzanilla: from 2011-01-01 to 2011-01-31
# Time elapsed (hh:mm:ss.ms) 0:01:52.483311
# Currently retrieving data for La_Manzanilla: from 2011-02-01 to 2011-02-28
# Time elapsed (hh:mm:ss.ms) 0:01:55.568878
# Currently retrieving data for La_Manzanilla: from 2011-03-01 to 2011-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:58.783331
# Currently retrieving data for La_Manzanilla: from 2011-04-01 to 2011-04-30
# Time elapsed (hh:mm:ss.ms) 0:02:06.317521
# Currently retrieving data for La_Manzanilla: from 2011-05-01 to 2011-05-31
# Time elapsed (hh:mm:ss.ms) 0:02:10.466629
# Currently retrieving data for La_Manzanilla: from 2011-06-01 to 2011-06-30
# Time elapsed (hh:mm:ss.ms) 0:02:15.132392
# Currently retrieving data for La_Manzanilla: from 2011-07-01 to 2011-07-31
# Time elapsed (hh:mm:ss.ms) 0:02:18.851137
# Currently retrieving data for La_Manzanilla: from 2011-08-01 to 2011-08-31
# Time elapsed (hh:mm:ss.ms) 0:02:23.571614
# Currently retrieving data for La_Manzanilla: from 2011-09-01 to 2011-09-30
# Time elapsed (hh:mm:ss.ms) 0:02:27.097472
# Currently retrieving data for La_Manzanilla: from 2011-10-01 to 2011-10-31
# Time elapsed (hh:mm:ss.ms) 0:02:30.647882
# Currently retrieving data for La_Manzanilla: from 2011-11-01 to 2011-11-30
# Time elapsed (hh:mm:ss.ms) 0:02:34.630917
# Currently retrieving data for La_Manzanilla: from 2011-12-01 to 2011-12-31
# Time elapsed (hh:mm:ss.ms) 0:02:43.561620
# Currently retrieving data for La_Manzanilla: from 2012-01-01 to 2012-01-31
# Time elapsed (hh:mm:ss.ms) 0:02:50.296671
# Currently retrieving data for La_Manzanilla: from 2012-02-01 to 2012-02-29
# Time elapsed (hh:mm:ss.ms) 0:02:53.711548
# Currently retrieving data for La_Manzanilla: from 2012-03-01 to 2012-03-31
# Time elapsed (hh:mm:ss.ms) 0:02:57.667038
# Currently retrieving data for La_Manzanilla: from 2012-04-01 to 2012-04-30
# Time elapsed (hh:mm:ss.ms) 0:03:01.875217
# Currently retrieving data for La_Manzanilla: from 2012-05-01 to 2012-05-31
# Time elapsed (hh:mm:ss.ms) 0:03:07.276150
# Currently retrieving data for La_Manzanilla: from 2012-06-01 to 2012-06-30
# Time elapsed (hh:mm:ss.ms) 0:03:10.726518
# Currently retrieving data for La_Manzanilla: from 2012-07-01 to 2012-07-31
# Time elapsed (hh:mm:ss.ms) 0:03:14.292207
# Currently retrieving data for La_Manzanilla: from 2012-08-01 to 2012-08-31
# Time elapsed (hh:mm:ss.ms) 0:03:17.609306
# Currently retrieving data for La_Manzanilla: from 2012-09-01 to 2012-09-30
# Time elapsed (hh:mm:ss.ms) 0:03:20.873667
# Currently retrieving data for La_Manzanilla: from 2012-10-01 to 2012-10-31
# Time elapsed (hh:mm:ss.ms) 0:03:24.721743
# Currently retrieving data for La_Manzanilla: from 2012-11-01 to 2012-11-30
# Time elapsed (hh:mm:ss.ms) 0:03:29.392591
# Currently retrieving data for La_Manzanilla: from 2012-12-01 to 2012-12-31
# Time elapsed (hh:mm:ss.ms) 0:03:32.915577
# Currently retrieving data for La_Manzanilla: from 2013-01-01 to 2013-01-31
# Time elapsed (hh:mm:ss.ms) 0:03:36.294051
# Currently retrieving data for La_Manzanilla: from 2013-02-01 to 2013-02-28
# Time elapsed (hh:mm:ss.ms) 0:03:40.657798
# Currently retrieving data for La_Manzanilla: from 2013-03-01 to 2013-03-31
# Time elapsed (hh:mm:ss.ms) 0:03:44.670803
# Currently retrieving data for La_Manzanilla: from 2013-04-01 to 2013-04-30
# Time elapsed (hh:mm:ss.ms) 0:03:50.410291
# Currently retrieving data for La_Manzanilla: from 2013-05-01 to 2013-05-31
# Time elapsed (hh:mm:ss.ms) 0:03:54.104495
# Currently retrieving data for La_Manzanilla: from 2013-06-01 to 2013-06-30
# Time elapsed (hh:mm:ss.ms) 0:03:59.085575
# Currently retrieving data for La_Manzanilla: from 2013-07-01 to 2013-07-31
# Time elapsed (hh:mm:ss.ms) 0:04:02.335198
# Currently retrieving data for La_Manzanilla: from 2013-08-01 to 2013-08-31
# Time elapsed (hh:mm:ss.ms) 0:04:05.654484
# Currently retrieving data for La_Manzanilla: from 2013-09-01 to 2013-09-30
# Time elapsed (hh:mm:ss.ms) 0:04:09.301081
# Currently retrieving data for La_Manzanilla: from 2013-10-01 to 2013-10-31
# Time elapsed (hh:mm:ss.ms) 0:04:13.300520
# Currently retrieving data for La_Manzanilla: from 2013-11-01 to 2013-11-30
# Time elapsed (hh:mm:ss.ms) 0:04:17.099962
# Currently retrieving data for La_Manzanilla: from 2013-12-01 to 2013-12-31
# Time elapsed (hh:mm:ss.ms) 0:04:23.399079
# Currently retrieving data for La_Manzanilla: from 2014-01-01 to 2014-01-31
# Time elapsed (hh:mm:ss.ms) 0:04:29.316216
# Currently retrieving data for La_Manzanilla: from 2014-02-01 to 2014-02-28
# Time elapsed (hh:mm:ss.ms) 0:04:32.998912
# Currently retrieving data for La_Manzanilla: from 2014-03-01 to 2014-03-31
# Time elapsed (hh:mm:ss.ms) 0:04:36.980888
# Currently retrieving data for La_Manzanilla: from 2014-04-01 to 2014-04-30
# Time elapsed (hh:mm:ss.ms) 0:04:43.580576
# Currently retrieving data for La_Manzanilla: from 2014-05-01 to 2014-05-31
# Time elapsed (hh:mm:ss.ms) 0:04:46.862818
# Currently retrieving data for La_Manzanilla: from 2014-06-01 to 2014-06-30
# Time elapsed (hh:mm:ss.ms) 0:04:50.762372
# Currently retrieving data for La_Manzanilla: from 2014-07-01 to 2014-07-31
# Time elapsed (hh:mm:ss.ms) 0:04:54.745215
# Currently retrieving data for La_Manzanilla: from 2014-08-01 to 2014-08-31
# Time elapsed (hh:mm:ss.ms) 0:04:58.845440
# Currently retrieving data for La_Manzanilla: from 2014-09-01 to 2014-09-30
# Time elapsed (hh:mm:ss.ms) 0:05:02.128581
# Currently retrieving data for La_Manzanilla: from 2014-10-01 to 2014-10-31
# Time elapsed (hh:mm:ss.ms) 0:05:06.660357
# Currently retrieving data for La_Manzanilla: from 2014-11-01 to 2014-11-30
# Time elapsed (hh:mm:ss.ms) 0:05:12.751230
# Currently retrieving data for La_Manzanilla: from 2014-12-01 to 2014-12-31
# Time elapsed (hh:mm:ss.ms) 0:05:17.109168
# Currently retrieving data for La_Manzanilla: from 2015-01-01 to 2015-01-31
# Time elapsed (hh:mm:ss.ms) 0:05:20.939064
# Currently retrieving data for La_Manzanilla: from 2015-02-01 to 2015-02-28
# Time elapsed (hh:mm:ss.ms) 0:05:24.306874
# Currently retrieving data for La_Manzanilla: from 2015-03-01 to 2015-03-31
# Time elapsed (hh:mm:ss.ms) 0:05:27.692925
# Currently retrieving data for La_Manzanilla: from 2015-04-01 to 2015-04-30
# Time elapsed (hh:mm:ss.ms) 0:05:32.990105
# Currently retrieving data for La_Manzanilla: from 2015-05-01 to 2015-05-31
# Time elapsed (hh:mm:ss.ms) 0:05:36.471930
# Currently retrieving data for La_Manzanilla: from 2015-06-01 to 2015-06-30
# Time elapsed (hh:mm:ss.ms) 0:05:40.206394
# Currently retrieving data for La_Manzanilla: from 2015-07-01 to 2015-07-31
# Time elapsed (hh:mm:ss.ms) 0:05:45.988510
# Currently retrieving data for La_Manzanilla: from 2015-08-01 to 2015-08-31
# Time elapsed (hh:mm:ss.ms) 0:05:50.938756
# Currently retrieving data for La_Manzanilla: from 2015-09-01 to 2015-09-30
# Time elapsed (hh:mm:ss.ms) 0:05:54.137350
# Currently retrieving data for La_Manzanilla: from 2015-10-01 to 2015-10-31
# Time elapsed (hh:mm:ss.ms) 0:05:57.387126
# Currently retrieving data for La_Manzanilla: from 2015-11-01 to 2015-11-30
# Time elapsed (hh:mm:ss.ms) 0:06:02.086555
# Currently retrieving data for La_Manzanilla: from 2015-12-01 to 2015-12-31
# Time elapsed (hh:mm:ss.ms) 0:06:06.919447
# Currently retrieving data for La_Manzanilla: from 2016-01-01 to 2016-01-31
# Time elapsed (hh:mm:ss.ms) 0:06:10.285495
# Currently retrieving data for La_Manzanilla: from 2016-02-01 to 2016-02-29
# Time elapsed (hh:mm:ss.ms) 0:06:14.401634
# Currently retrieving data for La_Manzanilla: from 2016-03-01 to 2016-03-31
# Time elapsed (hh:mm:ss.ms) 0:06:21.253574
# Currently retrieving data for La_Manzanilla: from 2016-04-01 to 2016-04-30
# Time elapsed (hh:mm:ss.ms) 0:06:25.283523
# Currently retrieving data for La_Manzanilla: from 2016-05-01 to 2016-05-31
# Time elapsed (hh:mm:ss.ms) 0:06:29.115283
# Currently retrieving data for La_Manzanilla: from 2016-06-01 to 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:06:32.499100
# Currently retrieving data for La_Manzanilla: from 2016-07-01 to 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:06:38.914034
# Currently retrieving data for La_Manzanilla: from 2016-08-01 to 2016-08-31
# Time elapsed (hh:mm:ss.ms) 0:06:42.531372
# Currently retrieving data for La_Manzanilla: from 2016-09-01 to 2016-09-30
# Time elapsed (hh:mm:ss.ms) 0:06:46.000560
# Currently retrieving data for La_Manzanilla: from 2016-10-01 to 2016-10-31
# Time elapsed (hh:mm:ss.ms) 0:06:49.268714
# Currently retrieving data for La_Manzanilla: from 2016-11-01 to 2016-11-30
# Time elapsed (hh:mm:ss.ms) 0:06:52.863377
# Currently retrieving data for La_Manzanilla: from 2016-12-01 to 2016-12-31
# Time elapsed (hh:mm:ss.ms) 0:06:56.446267
# Currently retrieving data for La_Manzanilla: from 2017-01-01 to 2017-01-31
# Time elapsed (hh:mm:ss.ms) 0:07:00.912369
# Currently retrieving data for La_Manzanilla: from 2017-02-01 to 2017-02-28
# Time elapsed (hh:mm:ss.ms) 0:07:04.779535
# Currently retrieving data for La_Manzanilla: from 2017-03-01 to 2017-03-31
# Time elapsed (hh:mm:ss.ms) 0:07:10.294442
# Currently retrieving data for La_Manzanilla: from 2017-04-01 to 2017-04-30
# Time elapsed (hh:mm:ss.ms) 0:07:14.282419
# Currently retrieving data for La_Manzanilla: from 2017-05-01 to 2017-05-31
# Time elapsed (hh:mm:ss.ms) 0:07:17.537204
# Currently retrieving data for La_Manzanilla: from 2017-06-01 to 2017-06-30
# Time elapsed (hh:mm:ss.ms) 0:07:21.243084
# Currently retrieving data for La_Manzanilla: from 2017-07-01 to 2017-07-31
# Time elapsed (hh:mm:ss.ms) 0:07:25.011159
# Currently retrieving data for La_Manzanilla: from 2017-08-01 to 2017-08-31
# Time elapsed (hh:mm:ss.ms) 0:07:28.609800
# Currently retrieving data for La_Manzanilla: from 2017-09-01 to 2017-09-30
# Time elapsed (hh:mm:ss.ms) 0:07:31.841470
# Currently retrieving data for La_Manzanilla: from 2017-10-01 to 2017-10-31
# Time elapsed (hh:mm:ss.ms) 0:07:35.207990
# Currently retrieving data for La_Manzanilla: from 2017-11-01 to 2017-11-30
# Time elapsed (hh:mm:ss.ms) 0:07:38.758456
# Currently retrieving data for La_Manzanilla: from 2017-12-01 to 2017-12-31
# Time elapsed (hh:mm:ss.ms) 0:07:43.141236
# Currently retrieving data for La_Manzanilla: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:07:48.373909
# Currently retrieving data for La_Manzanilla: from 2018-02-01 to 2018-02-28
# Time elapsed (hh:mm:ss.ms) 0:07:51.472454
# Currently retrieving data for La_Manzanilla: from 2018-03-01 to 2018-03-31
# Time elapsed (hh:mm:ss.ms) 0:07:56.771803
# Currently retrieving data for La_Manzanilla: from 2018-04-01 to 2018-04-30
# Time elapsed (hh:mm:ss.ms) 0:08:00.254656
# Currently retrieving data for La_Manzanilla: from 2018-05-01 to 2018-05-31
# Time elapsed (hh:mm:ss.ms) 0:08:05.287396
# Currently retrieving data for La_Manzanilla: from 2018-06-01 to 2018-06-30
# Time elapsed (hh:mm:ss.ms) 0:08:08.535796
# Currently retrieving data for La_Manzanilla: from 2018-07-01 to 2018-07-31
# Time elapsed (hh:mm:ss.ms) 0:08:13.989722
# Currently retrieving data for La_Manzanilla: from 2018-08-01 to 2018-08-31
# Time elapsed (hh:mm:ss.ms) 0:08:18.020135
# Currently retrieving data for La_Manzanilla: from 2018-09-01 to 2018-09-30
# Time elapsed (hh:mm:ss.ms) 0:08:21.940022
# Currently retrieving data for La_Manzanilla: from 2018-10-01 to 2018-10-31
# Time elapsed (hh:mm:ss.ms) 0:08:25.551281
# Currently retrieving data for La_Manzanilla: from 2018-11-01 to 2018-11-30
# Time elapsed (hh:mm:ss.ms) 0:08:29.372795
# Currently retrieving data for La_Manzanilla: from 2018-12-01 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:08:32.768573
# Currently retrieving data for La_Manzanilla: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:08:36.166667
# Currently retrieving data for La_Manzanilla: from 2019-02-01 to 2019-02-28
# Time elapsed (hh:mm:ss.ms) 0:08:39.849204
# Currently retrieving data for La_Manzanilla: from 2019-03-01 to 2019-03-31
# Time elapsed (hh:mm:ss.ms) 0:08:44.115782
# Currently retrieving data for La_Manzanilla: from 2019-04-01 to 2019-04-30
# Time elapsed (hh:mm:ss.ms) 0:08:49.002630
# Currently retrieving data for La_Manzanilla: from 2019-05-01 to 2019-05-31
# Time elapsed (hh:mm:ss.ms) 0:08:52.431374
# Currently retrieving data for La_Manzanilla: from 2019-06-01 to 2019-06-30
# Time elapsed (hh:mm:ss.ms) 0:08:55.713226
# Currently retrieving data for La_Manzanilla: from 2019-07-01 to 2019-07-31
# Time elapsed (hh:mm:ss.ms) 0:08:59.330056
# Currently retrieving data for La_Manzanilla: from 2019-08-01 to 2019-08-31
# Time elapsed (hh:mm:ss.ms) 0:09:02.664263
# Currently retrieving data for La_Manzanilla: from 2019-09-01 to 2019-09-30
# Time elapsed (hh:mm:ss.ms) 0:09:05.912866
# Currently retrieving data for La_Manzanilla: from 2019-10-01 to 2019-10-31
# Time elapsed (hh:mm:ss.ms) 0:09:10.510778
# Currently retrieving data for La_Manzanilla: from 2019-11-01 to 2019-11-30
# Time elapsed (hh:mm:ss.ms) 0:09:17.488960
# Currently retrieving data for La_Manzanilla: from 2019-12-01 to 2019-12-31
# Time elapsed (hh:mm:ss.ms) 0:09:27.310558
# Currently retrieving data for La_Manzanilla: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:09:30.842131
# Currently retrieving data for La_Manzanilla: from 2020-02-01 to 2020-02-21
# Time elapsed (hh:mm:ss.ms) 0:09:33.694243
#
#
# export La_Manzanilla completed!
